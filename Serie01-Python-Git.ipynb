# %% [markdown]
# # Serie01-PYTHON USING GIT AND GITUB

# %%
#Minimal script to see the ECG signal

# %%
#load the libraries 
import numpy as np
import matplotlib.pyplot as plt

#load the data
ecg_raw = np.loadtxt('data/ECGu.txt')
print(ecg_raw.shape)
plt.plot(ecg_raw)
# Out:
# (6500, 3)
# [<matplotlib.lines.Line2D at 0x12548d090>,
#  <matplotlib.lines.Line2D at 0x12548d1d0>,
#  <matplotlib.lines.Line2D at 0x12548d310>]

# %%
#plotthe data 
plt.plot(ecg_raw)
plt.title('ECG signal')
plt.xlabel('samples')
plt.ylabel('amplitude')
plt.grid()
plt.show()

# %%
# create t the time vector in seconds``
sampling_frequency = 1000 #in HZ
T = 1/ sampling_frequency
N = len(ecg_raw) #number of samples 
start = 0 
stop = (N - 1) * T #sampling frequency
t = np.linspace(start, stop, N)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 4
#       2 sampling_frequency = 1000 #in HZ
#       3 T = 1/ sampling_frequency
# ----> 4 N = len(ecg_raw) #number of samples
#       5 start = 0
#       6 stop = (N - 1) * T #sampling frequency
#
# NameError: name 'ecg_raw' is not defined
